# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
gdp_df.head(11)
# Out:
#    Country or Area  Year        Value  Value Footnotes
# 0      Afghanistan  2019  2065.036398              NaN
# 1      Afghanistan  2018  2033.779002              NaN
# 2      Afghanistan  2017  2058.383832              NaN
# 3      Afghanistan  2016  2057.062164              NaN
# 4      Afghanistan  2015  2068.265904              NaN
# 5      Afghanistan  2014  2102.385234              NaN
# 6      Afghanistan  2013  2116.465454              NaN
# 7      Afghanistan  2012  2075.491747              NaN
# 8      Afghanistan  2011  1904.559799              NaN
# 9      Afghanistan  2010  1957.029338              NaN
# 10     Afghanistan  2009  1758.904043              NaN

# %%
gdp_df.head(-6)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
#
# [6864 rows x 4 columns]

# %%
gdp_df = gdp_df.drop(['Value Footnotes'],axis = 1)

# %%
gdp_df.rename(columns = {'Country or Area': 'Country', 'Value': 'GDP_PER_Capita'}, inplace = True)

# %%
print(gdp_df.columns)
# Out:
# Index(['Country', 'Year', 'GDP_PER_Capita'], dtype='object')

# %%
gdp_df
# Out:
#             Country                                      Year  GDP_PER_Capita
# 0       Afghanistan                                      2019     2065.036398
# 1       Afghanistan                                      2018     2033.779002
# 2       Afghanistan                                      2017     2058.383832
# 3       Afghanistan                                      2016     2057.062164
# 4       Afghanistan                                      2015     2068.265904
# ...             ...                                       ...             ...
# 6865       Zimbabwe                                      1992     3054.889178
# 6866       Zimbabwe                                      1991     3426.598094
# 6867       Zimbabwe                                      1990     3324.348171
# 6868  footnoteSeqID                                  Footnote             NaN
# 6869              2  Excludes South Sudan after July 9, 2011.             NaN
#
# [6870 rows x 3 columns]

# %%
gdp_2014 = gdp_df[gdp_df['Year'] == '2014']

# %%
gdp_2014.describe()
# Out:
#        GDP_PER_Capita
# count      238.000000
# mean     19766.710348
# std      20983.869623
# min        822.610458
# 25%       4753.110934
# 50%      12209.385755
# 75%      26803.610474
# max     156514.133850

# %%
gdp_2014.hist(bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'GDP_PER_Capita'}>]], dtype=object)

# %%
gdp_2014[gdp_2014['Country'] > 'GDP_PER_Capita']
# Out:
#                  Country  Year  GDP_PER_Capita
# 2116               Gabon  2014    15437.273224
# 2146             Georgia  2014    12254.645655
# 2176             Germany  2014    50932.756778
# 2206               Ghana  2014     4675.758566
# 2236              Greece  2014    28615.837733
# ...                  ...   ...             ...
# 6727             Vietnam  2014     6098.489609
# 6757  West Bank and Gaza  2014     5967.073437
# 6783               World  2014    15189.648507
# 6813              Zambia  2014     3450.046561
# 6843            Zimbabwe  2014     2955.240287
#
# [165 rows x 3 columns]

# %%
gdp_df.pivot_table(index = 'Country', columns = "Year", values = 'GDP_PER_Capita')
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Afghanistan                   NaN           NaN           NaN           NaN
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# ...                           ...           ...           ...           ...
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# West Bank and Gaza            NaN           NaN           NaN           NaN
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivot = gdp_df.pivot_table(index = 'Country', values = 'GDP_PER_Capita', columns = 'Year')

# %%
gdp_pivot.head()
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Afghanistan                   NaN           NaN           NaN           NaN
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
#
# Year                         1994          1995          1996          1997  \
# Country
# Afghanistan                   NaN           NaN           NaN           NaN
# Albania               3934.375728   4486.152092   4924.905836   4414.631173
# Algeria               7792.085182   7935.179841   8116.962721   8074.759953
# Angola                3717.366881   4139.640473   4551.651329   4728.157560
# Antigua and Barbuda  16697.248772  15628.396992  16303.723892  16828.640823
#
# ...

# %%
gdp_pivot = gdp_pivot.dropna()

# %%
gdp_pivoted = gdp_pivot[['1990', '2017']]

# %%
gdp_pivoted
# Out:
# Year                         1990          2017
# Country
# Albania               4842.734635  12811.759436
# Algeria               8746.352901  11737.409353
# Angola                5783.429064   7310.901738
# Antigua and Barbuda  15459.551675  19840.076123
# Arab World            9694.667544  14555.474921
# ...                           ...           ...
# Vanuatu               2888.309393   3116.645194
# Vietnam               1673.249634   7155.745829
# World                 9680.269697  16253.385518
# Zambia                2190.182814   3485.005238
# Zimbabwe              3324.348171   3028.245976
#
# [203 rows x 2 columns]

# %%
GDP = gdp_pivot['1990'] - gdp_pivot['2017']

# %%
GDP
# Out:
# Country
# Albania               -7969.024801
# Algeria               -2991.056452
# Angola                -1527.472674
# Antigua and Barbuda   -4380.524448
# Arab World            -4860.807377
#                           ...
# Vanuatu                -228.335801
# Vietnam               -5482.496195
# World                 -6573.115820
# Zambia                -1294.822424
# Zimbabwe                296.102195
# Length: 203, dtype: float64

# %%
gdp_pivoted['Percent_Change'] = GDP
# Out:
# C:\Users\tjsim\AppData\Local\Temp\ipykernel_28868\2970259772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_pivoted['Percent_Change'] = GDP

# %%
gdp_pivoted
# Out:
# Year                         1990      percent          2017  Percent_Change  \
# Country
# Albania               4842.734635 -7969.024801  12811.759436    -7969.024801
# Algeria               8746.352901 -2991.056452  11737.409353    -2991.056452
# Angola                5783.429064 -1527.472674   7310.901738    -1527.472674
# Antigua and Barbuda  15459.551675 -4380.524448  19840.076123    -4380.524448
# Arab World            9694.667544 -4860.807377  14555.474921    -4860.807377
# ...                           ...          ...           ...             ...
# Vanuatu               2888.309393  -228.335801   3116.645194     -228.335801
# Vietnam               1673.249634 -5482.496195   7155.745829    -5482.496195
# World                 9680.269697 -6573.115820  16253.385518    -6573.115820
# Zambia                2190.182814 -1294.822424   3485.005238    -1294.822424
# Zimbabwe              3324.348171   296.102195   3028.245976      296.102195
#
# ...

# %%
gdp_pivoted = gdp_pivoted.drop(['percent', 'Pivoted_Change'],axis = 1)

# %%
gdp_pivoted
# Out:
# Year                         1990          2017  Percent_Change
# Country
# Albania               4842.734635  12811.759436    -7969.024801
# Algeria               8746.352901  11737.409353    -2991.056452
# Angola                5783.429064   7310.901738    -1527.472674
# Antigua and Barbuda  15459.551675  19840.076123    -4380.524448
# Arab World            9694.667544  14555.474921    -4860.807377
# ...                           ...           ...             ...
# Vanuatu               2888.309393   3116.645194     -228.335801
# Vietnam               1673.249634   7155.745829    -5482.496195
# World                 9680.269697  16253.385518    -6573.115820
# Zambia                2190.182814   3485.005238    -1294.822424
# Zimbabwe              3324.348171   3028.245976      296.102195
#
# [203 rows x 3 columns]

# %%
gdp_pivoted.sort_values(['Percent_Change'], ascending = False)
# Out:
# Year                           1990           2017  Percent_Change
# Country
# United Arab Emirates  111454.360446   67183.626557    44270.733889
# Brunei                 71230.862143   60995.681114    10235.181029
# Ukraine                15751.722440   11871.123624     3880.598816
# Gabon                  18179.265733   15006.764091     3172.501642
# The Bahamas            38099.848616   36297.307023     1802.541593
# ...                             ...            ...             ...
# Hong Kong SAR, China   28798.323939   59849.248176   -31050.924237
# Luxembourg             67857.540495  112666.769445   -44809.228950
# Ireland                26448.289360   78051.520996   -51603.231636
# Singapore              37348.206786   94940.970785   -57592.763999
# Macao SAR, China       48452.817991  126918.226522   -78465.408530
#
# [203 rows x 3 columns]

# %%
x = ('Year': ['1990', '2017'],
     'Country': [0],
     'Percent_Change': [x*2]
# Out:
#   Input In [158]
#     x = ('Year': ['1990', '2017'],
#                ^
# SyntaxError: invalid syntax

# %%
plt.plot(x, y)
plt.title('United Arab Emirates')
plt.xlabel(x)
plt.ylabel(y)
plt.show()
# Out:
# C:\Users\tjsim\Anaconda\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
## 6870 rows x 4 columns ##
## Floats and Objects ##
## ? ##

# %%
## years in set = 1990 - 2019. There is an increase in observations each year, which would indicate pop growth##
## 240 countries ##
