# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df.head(11)
# Out:
#    Country or Area  Year        Value  Value Footnotes
# 0      Afghanistan  2019  2065.036398              NaN
# 1      Afghanistan  2018  2033.779002              NaN
# 2      Afghanistan  2017  2058.383832              NaN
# 3      Afghanistan  2016  2057.062164              NaN
# 4      Afghanistan  2015  2068.265904              NaN
# 5      Afghanistan  2014  2102.385234              NaN
# 6      Afghanistan  2013  2116.465454              NaN
# 7      Afghanistan  2012  2075.491747              NaN
# 8      Afghanistan  2011  1904.559799              NaN
# 9      Afghanistan  2010  1957.029338              NaN
# 10     Afghanistan  2009  1758.904043              NaN

# %%
gdp_df.head(-6)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
#
# [6864 rows x 4 columns]

# %%
gdp_df = gdp_df.drop(['Value Footnotes'],axis = 1)

# %%
gdp_df.rename(columns = {'Country or Area': 'Country', 'Value': 'GDP_PER_Capita'}, inplace = True)

# %%
print(gdp_df.columns)
# Out:
# Index(['Country', 'Year', 'GDP_PER_Capita'], dtype='object')

# %%
gdp_df
# Out:
#             Country                                      Year  GDP_PER_Capita
# 0       Afghanistan                                      2019     2065.036398
# 1       Afghanistan                                      2018     2033.779002
# 2       Afghanistan                                      2017     2058.383832
# 3       Afghanistan                                      2016     2057.062164
# 4       Afghanistan                                      2015     2068.265904
# ...             ...                                       ...             ...
# 6865       Zimbabwe                                      1992     3054.889178
# 6866       Zimbabwe                                      1991     3426.598094
# 6867       Zimbabwe                                      1990     3324.348171
# 6868  footnoteSeqID                                  Footnote             NaN
# 6869              2  Excludes South Sudan after July 9, 2011.             NaN
#
# [6870 rows x 3 columns]

# %%
gdp_2014 = gdp_df[gdp_df['Year'] == '2014']

# %%
gdp_2014.describe()
# Out:
#        GDP_PER_Capita
# count      238.000000
# mean     19766.710348
# std      20983.869623
# min        822.610458
# 25%       4753.110934
# 50%      12209.385755
# 75%      26803.610474
# max     156514.133850

# %%
gdp_2014.hist(bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'GDP_PER_Capita'}>]], dtype=object)

# %%
gdp_2014[gdp_2014['Country'] > 'GDP_PER_Capita']
# Out:
#                  Country  Year  GDP_PER_Capita
# 2116               Gabon  2014    15437.273224
# 2146             Georgia  2014    12254.645655
# 2176             Germany  2014    50932.756778
# 2206               Ghana  2014     4675.758566
# 2236              Greece  2014    28615.837733
# ...                  ...   ...             ...
# 6727             Vietnam  2014     6098.489609
# 6757  West Bank and Gaza  2014     5967.073437
# 6783               World  2014    15189.648507
# 6813              Zambia  2014     3450.046561
# 6843            Zimbabwe  2014     2955.240287
#
# [165 rows x 3 columns]

# %%
gdp_df = gdp_df.reset_index()

# %%
gdp_df = gdp_df.pivot_table('GDP_PER_Capita', index = ['Country'], columns = 'Year')
gdp_df
# Out:
# Year                         1990          1991          1992          1993  \
# Country
# Afghanistan                   NaN           NaN           NaN           NaN
# Albania               4842.734635   3507.746654   3275.444336   3610.520633
# Algeria               8746.352901   8431.385028   8383.770248   8027.376688
# Angola                5783.429064   5649.782130   5148.252824   3788.508107
# Antigua and Barbuda  15459.551675  15586.896172  15497.464744  15991.764201
# ...                           ...           ...           ...           ...
# Vietnam               1673.249634   1736.014139   1847.620675   1957.644497
# West Bank and Gaza            NaN           NaN           NaN           NaN
# World                 9680.269697   9645.256163   9647.070526   9657.888486
# Zambia                2190.182814   2133.689042   2045.973257   2133.263108
# Zimbabwe              3324.348171   3426.598094   3054.889178   3033.504852
#
# ...

# %%
gdp_pivoted = gdp_df[['1990', '2017']]

# %%
gdp_df[['1990', '2017']]
# Out:
# Year                         1990          2017
# Country
# Afghanistan                   NaN   2058.383832
# Albania               4842.734635  12811.759436
# Algeria               8746.352901  11737.409353
# Angola                5783.429064   7310.901738
# Antigua and Barbuda  15459.551675  19840.076123
# ...                           ...           ...
# Vietnam               1673.249634   7155.745829
# West Bank and Gaza            NaN   6401.740891
# World                 9680.269697  16253.385518
# Zambia                2190.182814   3485.005238
# Zimbabwe              3324.348171   3028.245976
#
# [238 rows x 2 columns]

# %%
gdp_pivoted
# Out:
# Year                         1990          2017
# Country
# Afghanistan                   NaN   2058.383832
# Albania               4842.734635  12811.759436
# Algeria               8746.352901  11737.409353
# Angola                5783.429064   7310.901738
# Antigua and Barbuda  15459.551675  19840.076123
# ...                           ...           ...
# Vietnam               1673.249634   7155.745829
# West Bank and Gaza            NaN   6401.740891
# World                 9680.269697  16253.385518
# Zambia                2190.182814   3485.005238
# Zimbabwe              3324.348171   3028.245976
#
# [238 rows x 2 columns]

# %%
PC = 100 * ((gdp_pivoted['2017'] - gdp_pivoted['1990'])/ (gdp_pivoted['2017']))

# %%
PC
# Out:
# Country
# Afghanistan                  NaN
# Albania                62.200862
# Algeria                25.483106
# Angola                 20.893082
# Antigua and Barbuda    22.079172
#                          ...
# Vietnam                76.616698
# West Bank and Gaza           NaN
# World                  40.441518
# Zambia                 37.154103
# Zimbabwe               -9.778010
# Length: 238, dtype: float64

# %%
gdp_pivoted["Percent_Change"] = PC
# Out:
# C:\Users\tjsim\AppData\Local\Temp\ipykernel_150728\2620868147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_pivoted["Percent_Change"] = PC

# %%
gdp_pivoted
# Out:
# Year                         1990          2017  Percent_Change
# Country
# Afghanistan                   NaN   2058.383832             NaN
# Albania               4842.734635  12811.759436       62.200862
# Algeria               8746.352901  11737.409353       25.483106
# Angola                5783.429064   7310.901738       20.893082
# Antigua and Barbuda  15459.551675  19840.076123       22.079172
# ...                           ...           ...             ...
# Vietnam               1673.249634   7155.745829       76.616698
# West Bank and Gaza            NaN   6401.740891             NaN
# World                 9680.269697  16253.385518       40.441518
# Zambia                2190.182814   3485.005238       37.154103
# Zimbabwe              3324.348171   3028.245976       -9.778010
#
# [238 rows x 3 columns]

# %%
gdp_pivoted.dropna()
# Out:
# Year                         1990          2017  Percent_Change
# Country
# Albania               4842.734635  12811.759436       62.200862
# Algeria               8746.352901  11737.409353       25.483106
# Angola                5783.429064   7310.901738       20.893082
# Antigua and Barbuda  15459.551675  19840.076123       22.079172
# Arab World            9694.667544  14555.474921       33.395045
# ...                           ...           ...             ...
# Vanuatu               2888.309393   3116.645194        7.326333
# Vietnam               1673.249634   7155.745829       76.616698
# World                 9680.269697  16253.385518       40.441518
# Zambia                2190.182814   3485.005238       37.154103
# Zimbabwe              3324.348171   3028.245976       -9.778010
#
# [207 rows x 3 columns]

# %%
gdp_pivoted.sort_values(['Percent_Change'], ascending = False)
# Out:
# Year                                                1990          2017  \
# Country
# Equatorial Guinea                            1039.985049  22551.083246
# China                                        1423.896348  14344.421239
# Myanmar                                       619.645144   4739.910118
# East Asia & Pacific (excluding high income)  2173.223895  12986.322227
# East Asia & Pacific (IDA & IBRD)             2196.950288  13123.151792
# ...                                                  ...           ...
# Small states                                         NaN  20448.504101
# Ṣo Tom̩ and Principe                              NaN   3952.888147
# Timor-Leste                                          NaN   3145.480591
# Turks and Caicos Islands                             NaN  27061.318758
# West Bank and Gaza                                   NaN   6401.740891
#
# Year                                         Percent_Change
# Country
# ...

# %%
gdp_df.loc['Equatorial Guinea'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
gdp_df.loc['China'].plot(kind = 'line')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
continents = pd.read_csv('../data/continents.csv')

# %%
continents.head()
# Out:
#   Continent      Country
# 0      Asia  Afghanistan
# 1    Europe      Albania
# 2    Africa      Algeria
# 3    Europe      Andorra
# 4    Africa       Angola

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area': 'Country'})

# %%
gdp_df = pd.merge(gdp_df, continents, how = 'outer')

# %%
gdp_df = gdp_df[gdp_df['Year'] == '2019']

# %%
gdp_df.groupby('Continent')['Country'].count()
# Out:
# Continent
# Africa           49
# Asia             42
# Europe           44
# North America    24
# Oceania          12
# South America    11
# Name: Country, dtype: int64

# %%
gdp_df.groupby('Continent')['Country'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Continent'>

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
continents = pd.read_csv('../data/continents.csv')

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area': 'Country'})

# %%
gdp_df = pd.merge(gdp_df, continents, how = 'outer')

# %%
gdp_df
# Out:
#            Country  Year        Value  Value Footnotes      Continent
# 0      Afghanistan  2019  2065.036398              NaN           Asia
# 1      Afghanistan  2018  2033.779002              NaN           Asia
# 2      Afghanistan  2017  2058.383832              NaN           Asia
# 3      Afghanistan  2016  2057.062164              NaN           Asia
# 4      Afghanistan  2015  2068.265904              NaN           Asia
# ...            ...   ...          ...              ...            ...
# 6893     Swaziland   NaN          NaN              NaN         Africa
# 6894         Syria   NaN          NaN              NaN           Asia
# 6895  Vatican City   NaN          NaN              NaN         Europe
# 6896     Venezuela   NaN          NaN              NaN  South America
# 6897         Yemen   NaN          NaN              NaN           Asia
#
# [6898 rows x 5 columns]

# %%
gdp_df = gdp_df[gdp_df['Year'] == '2014']

# %%
gdp_df
# Out:
#                   Country  Year         Value  Value Footnotes      Continent
# 5             Afghanistan  2014   2102.385234              NaN           Asia
# 23                Albania  2014  11623.866679              NaN         Europe
# 53                Algeria  2014  11512.705405              NaN         Africa
# 83                 Angola  2014   8239.828837              NaN         Africa
# 113   Antigua and Barbuda  2014  18104.241470              NaN  North America
# ...                   ...   ...           ...              ...            ...
# 6727              Vietnam  2014   6098.489609              NaN           Asia
# 6757   West Bank and Gaza  2014   5967.073437              NaN           Asia
# 6783                World  2014  15189.648507              NaN            NaN
# 6813               Zambia  2014   3450.046561              NaN         Africa
# 6843             Zimbabwe  2014   2955.240287              NaN         Africa
#
# [238 rows x 5 columns]

# %%
gdp_df = gdp_df.rename(columns = {'Value': 'GDP_PER_Capita'})

# %%
gdp_df
# Out:
#                   Country  Year  GDP_PER_Capita  Value Footnotes  \
# 5             Afghanistan  2014     2102.385234              NaN
# 23                Albania  2014    11623.866679              NaN
# 53                Algeria  2014    11512.705405              NaN
# 83                 Angola  2014     8239.828837              NaN
# 113   Antigua and Barbuda  2014    18104.241470              NaN
# ...                   ...   ...             ...              ...
# 6727              Vietnam  2014     6098.489609              NaN
# 6757   West Bank and Gaza  2014     5967.073437              NaN
# 6783                World  2014    15189.648507              NaN
# 6813               Zambia  2014     3450.046561              NaN
# 6843             Zimbabwe  2014     2955.240287              NaN
#
#           Continent
# 5              Asia
# 23           Europe
# 53           Africa
# 83           Africa
# 113   North America
# ...             ...
# 6727           Asia
# ...

# %%
gdp_df.boxplot(by = 'Continent', column = ['GDP_PER_Capita'], grid = False, figsize = (20,10), color = 'Red')
# Out:
# <AxesSubplot:title={'center':'GDP_PER_Capita'}, xlabel='Continent'>

# %%
life_expectancy = pd.read_csv('../data/WorldBank.csv')

# %%
life_expectancy = life_expectancy.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis = 1)

# %%
life_expectancy
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                            NaN        NaN        NaN        NaN        NaN
# 1                          Aruba  65.662000  66.074000  66.444000  66.787000
# 2    Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# 3                    Afghanistan  32.446000  32.962000  33.471000  33.971000
# 4     Africa Western and Central  37.205380  37.632546  38.052612  38.463746
# ..                           ...        ...        ...        ...        ...
# 262                       Kosovo        NaN        NaN        NaN        NaN
# 263                  Yemen, Rep.  29.919000  30.163000  30.500000  30.943000
# 264                 South Africa  48.406000  48.777000  49.142000  49.509000
# 265                       Zambia  46.687000  47.084000  47.446000  47.772000
# 266                     Zimbabwe  53.019000  53.483000  53.946000  54.403000
#
# ...

# %%
gdp_le = life_expectancy.melt(id_vars='Country Name')

# %%
gdp_le.sort_values(by = 'value', ascending = False).head()
# Out:
#                Country Name variable      value
# 16117  Hong Kong SAR, China     2020  85.387805
# 15850  Hong Kong SAR, China     2019  85.078049
# 15583  Hong Kong SAR, China     2018  84.934146
# 15316  Hong Kong SAR, China     2017  84.680488
# 16140                 Japan     2020  84.615610

# %%
gdp_le = gdp_le[gdp_le['variable'] == '2019']

# %%
gdp_le.dropna()
# Out:
#                       Country Name variable      value
# 15754                        Aruba     2019  76.293000
# 15755  Africa Eastern and Southern     2019  64.005213
# 15756                  Afghanistan     2019  64.833000
# 15757   Africa Western and Central     2019  58.115723
# 15758                       Angola     2019  61.147000
# ...                            ...      ...        ...
# 16015                       Kosovo     2019  73.092683
# 16016                  Yemen, Rep.     2019  66.125000
# 16017                 South Africa     2019  64.131000
# 16018                       Zambia     2019  63.886000
# 16019                     Zimbabwe     2019  61.490000
#
# [247 rows x 3 columns]

# %%
gdp_le[gdp_le['value'] >= 80].count()
# Out:
# Country Name    43
# variable        43
# value           43
# dtype: int64

# %%
gdp_le = gdp_le.sort_values(by = 'value', ascending = False).head(3)

# %%
gdp_le
# Out:
#                Country Name variable      value
# 15850  Hong Kong SAR, China     2019  85.078049
# 15873                 Japan     2019  84.356341
# 15900      Macao SAR, China     2019  84.244000

# %%
top_le = life_expectancy.reset_index()

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
gdp_df_2019 = gdp_df[gdp_df['Year'] == '2019']

# %%
gdp_df_2019 = gdp_df_2019.rename(columns = {'Value': "GDP_PER_Capita"})

# %%
gdp_df_2019 = gdp_df_2019.sort_values(by = 'GDP_PER_Capita', ascending = False).head(3)

# %%
gdp_df_2019
# Out:
#        Country or Area  Year  GDP_PER_Capita  Value Footnotes
# 3716  Macao SAR, China  2019   123965.286432              NaN
# 3686        Luxembourg  2019   114304.044210              NaN
# 5459         Singapore  2019    97341.468645              NaN

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv')

# %%
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df = gdp_df.set_index('Country or Area')

# %%
gdp_df = gdp_df.loc[['Macao SAR, China', 'Luxembourg', 'Singapore']]

# %%
gdp_df
# Out:
#                   Year          Value  Value Footnotes
# Country or Area
# Macao SAR, China  2019  123965.286432              NaN
# Macao SAR, China  2018  131908.154163              NaN
# Macao SAR, China  2017  126918.226522              NaN
# Macao SAR, China  2016  117335.587800              NaN
# Macao SAR, China  2015  120294.895762              NaN
# ...                ...            ...              ...
# Singapore         1994   46895.053010              NaN
# Singapore         1993   43555.619036              NaN
# Singapore         1992   40077.548794              NaN
# Singapore         1991   38728.403909              NaN
# Singapore         1990   37348.206786              NaN
#
# [90 rows x 3 columns]

# %%
gdp_df = gdp_df.reset_index()

# %%
gdp_df = gdp_df.drop(['Value Footnotes'], axis =1)

# %%
gdp_df = gdp_df.rename(columns = {'Country or Area': 'Country', 'Value': 'GDP_PER_Capita'})

# %%
gdp_df
# Out:
#              Country  Year  GDP_PER_Capita
# 0   Macao SAR, China  2019   123965.286432
# 1   Macao SAR, China  2018   131908.154163
# 2   Macao SAR, China  2017   126918.226522
# 3   Macao SAR, China  2016   117335.587800
# 4   Macao SAR, China  2015   120294.895762
# ..               ...   ...             ...
# 85         Singapore  1994    46895.053010
# 86         Singapore  1993    43555.619036
# 87         Singapore  1992    40077.548794
# 88         Singapore  1991    38728.403909
# 89         Singapore  1990    37348.206786
#
# [90 rows x 3 columns]

# %%
gdp_df_Facet = sns.FacetGrid(gdp_df, col = 'Country', height = 4, aspect = 1.5)
gdp_df_Facet.map(plt.hist, 'GDP_PER_Capita', bins = 10, color = 'r')

# %%
life_expectancy = pd.read_csv('../data/WorldBank.csv')

# %%
life_expectancy.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis = 1)
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                            NaN        NaN        NaN        NaN        NaN
# 1                          Aruba  65.662000  66.074000  66.444000  66.787000
# 2    Africa Eastern and Southern  42.716053  43.166935  43.603990  44.025617
# 3                    Afghanistan  32.446000  32.962000  33.471000  33.971000
# 4     Africa Western and Central  37.205380  37.632546  38.052612  38.463746
# ..                           ...        ...        ...        ...        ...
# 262                       Kosovo        NaN        NaN        NaN        NaN
# 263                  Yemen, Rep.  29.919000  30.163000  30.500000  30.943000
# 264                 South Africa  48.406000  48.777000  49.142000  49.509000
# 265                       Zambia  46.687000  47.084000  47.446000  47.772000
# 266                     Zimbabwe  53.019000  53.483000  53.946000  54.403000
#
# ...

# %%
life_expectancy = life_expectancy[['2019', 'Country Name']].dropna()
life_expectancy
# Out:
#           2019                 Country Name
# 1    76.293000                        Aruba
# 2    64.005213  Africa Eastern and Southern
# 3    64.833000                  Afghanistan
# 4    58.115723   Africa Western and Central
# 5    61.147000                       Angola
# ..         ...                          ...
# 262  73.092683                       Kosovo
# 263  66.125000                  Yemen, Rep.
# 264  64.131000                 South Africa
# 265  63.886000                       Zambia
# 266  61.490000                     Zimbabwe
#
# [247 rows x 2 columns]

# %%
gdp_df = pd.read_csv('../data/UNdata_Export_20220916_042202532.csv') 
gdp_df
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2019  2065.036398
# 1        Afghanistan                                      2018  2033.779002
# 2        Afghanistan                                      2017  2058.383832
# 3        Afghanistan                                      2016  2057.062164
# 4        Afghanistan                                      2015  2068.265904
# ...              ...                                       ...          ...
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# ...

# %%
gdp_df = gdp_df[gdp_df['Year'] == '2019']

# %%
gdp_df = gdp_df.drop(['Value Footnotes'], axis = 1)

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country Name', 'Value': 'GDP_PER_Capita'})
gdp_df
# Out:
#              Country Name  Year  GDP_PER_Capita
# 0             Afghanistan  2019     2065.036398
# 18                Albania  2019    13724.058790
# 48                Algeria  2019    11510.557088
# 78                 Angola  2019     6670.332297
# 108   Antigua and Barbuda  2019    21910.184985
# ...                   ...   ...             ...
# 6722              Vietnam  2019     8041.178551
# 6752   West Bank and Gaza  2019     6219.960291
# 6778                World  2019    16911.193295
# 6808               Zambia  2019     3470.448801
# 6838             Zimbabwe  2019     2835.948532
#
# [231 rows x 3 columns]

# %%
gdp_le_2019 = pd.merge(gdp_df, life_expectancy, how = 'outer')

# %%
gdp_le_2019 = gdp_le_2019.dropna()

# %%
gdp_le_2019 = gdp_le_2019.rename(columns = {'2019': 'life_expectancy'})

# %%
gdp_le_2019.plot(kind = 'scatter', x = 'life_expectancy', y = 'GDP_PER_Capita')
# Out:
# <AxesSubplot:xlabel='life_expectancy', ylabel='GDP_PER_Capita'>

# %%
gdp_le_2019.corr()
# Out:
#                  GDP_PER_Capita  life_expectancy  gdp_le_log
# GDP_PER_Capita         1.000000         0.722822    0.855023
# life_expectancy        0.722822         1.000000    0.857329
# gdp_le_log             0.855023         0.857329    1.000000

# %%
gdp_le_2019['log'] = np.log2(gdp_le_2019['GDP_PER_Capita'])

# %%
gdp_le_2019['gdp_le_log'] = gdp_le_2019['log']

# %%
gdp_le_2019
# Out:
#             Country Name  Year  GDP_PER_Capita  life_expectancy  gdp_le_log
# 0            Afghanistan  2019     2065.036398        64.833000   11.011951
# 1                Albania  2019    13724.058790        78.573000   13.744420
# 2                Algeria  2019    11510.557088        76.880000   13.490670
# 3                 Angola  2019     6670.332297        61.147000   12.703543
# 4    Antigua and Barbuda  2019    21910.184985        77.016000   14.419314
# ..                   ...   ...             ...              ...         ...
# 226              Vietnam  2019     8041.178551        75.400000   12.973191
# 227   West Bank and Gaza  2019     6219.960291        74.053000   12.602690
# 228                World  2019    16911.193295        72.763223   14.045691
# 229               Zambia  2019     3470.448801        63.886000   11.760907
# 230             Zimbabwe  2019     2835.948532        61.490000   11.469616
#
# [207 rows x 5 columns]

# %%
gdp_le_2019.corr()
# Out:
#                  GDP_PER_Capita  life_expectancy  gdp_le_log
# GDP_PER_Capita         1.000000         0.722822    0.855023
# life_expectancy        0.722822         1.000000    0.857329
# gdp_le_log             0.855023         0.857329    1.000000

# %%
gdp_le_2019.rename(columns = {'2019': 'life_expectancy'})
# Out:
#             Country Name  Year  GDP_PER_Capita  life_expectancy  gdp_le_log
# 0            Afghanistan  2019     2065.036398        64.833000   11.011951
# 1                Albania  2019    13724.058790        78.573000   13.744420
# 2                Algeria  2019    11510.557088        76.880000   13.490670
# 3                 Angola  2019     6670.332297        61.147000   12.703543
# 4    Antigua and Barbuda  2019    21910.184985        77.016000   14.419314
# ..                   ...   ...             ...              ...         ...
# 226              Vietnam  2019     8041.178551        75.400000   12.973191
# 227   West Bank and Gaza  2019     6219.960291        74.053000   12.602690
# 228                World  2019    16911.193295        72.763223   14.045691
# 229               Zambia  2019     3470.448801        63.886000   11.760907
# 230             Zimbabwe  2019     2835.948532        61.490000   11.469616
#
# [207 rows x 5 columns]
