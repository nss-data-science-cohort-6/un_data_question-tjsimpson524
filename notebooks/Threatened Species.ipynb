# %%
import pandas as pd

# %%
species = pd.read_csv('../data/SYB64_313_202110_Threatened Species.csv')

# %%
species
# Out:
#                       T23 Threatened species Unnamed: 2  \
# 0     Region/Country/Area                NaN       Year
# 1                       4        Afghanistan       2004
# 2                       4        Afghanistan       2010
# 3                       4        Afghanistan       2015
# 4                       4        Afghanistan       2018
# ...                   ...                ...        ...
# 6916                  716           Zimbabwe       2015
# 6917                  716           Zimbabwe       2018
# 6918                  716           Zimbabwe       2019
# 6919                  716           Zimbabwe       2020
# 6920                  716           Zimbabwe       2021
#
#                                     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                       Series      Value  Footnotes
# 1     Threatened Species: Vertebrates (number)         31        NaN
# 2     Threatened Species: Vertebrates (number)         31        NaN
# ...

# %%
species.describe()
# Out:
#          T23 Threatened species Unnamed: 2  \
# count   6921               6920       6921
# unique   254                253          8
# top      422        Afghanistan       2021
# freq      28                 28        999
#
#                                 Unnamed: 3 Unnamed: 4  \
# count                                 6921       6921
# unique                                   5        628
# top     Threatened Species: Total (number)          0
# freq                                  1731        490
#
#                              Unnamed: 5  \
# count                               115
# unique                                6
# top     Excluding overseas territories.
# freq                                 28
#
#                                                Unnamed: 6
# count                                                6921
# unique                                                  2
# top     World Conservation Union (IUCN), Gland and Cam...
# ...

# %%
species.loc[10]
# Out:
# T23                                                                   4
# Threatened species                                          Afghanistan
# Unnamed: 2                                                         2015
# Unnamed: 3                   Threatened Species: Invertebrates (number)
# Unnamed: 4                                                            2
# Unnamed: 5                                                          NaN
# Unnamed: 6            World Conservation Union (IUCN), Gland and Cam...
# Name: 10, dtype: object
