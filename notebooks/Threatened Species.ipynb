# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# US would be in top 20 of the world
# Us would have improved over years
# GDP would relate to threatened species for the top 10 countries

# %%
species = pd.read_csv('../data/SYB64_313_202110_Threatened Species.csv')

# %%
species = species.drop(columns = 'T23')

# %%
species = species.rename(columns = {'Threatened species': 'Country',
                                    'Unnamed: 2': 'Year', 
                                    'Unnamed: 3': 'Threatened species', 
                                    'Unnamed: 4': 'Value', 
                                    'Unnamed: 6': 'Source'})

# %%
species
# Out:
#           Country  Year                        Threatened species  Value  \
# 0             NaN  Year                                    Series  Value
# 1     Afghanistan  2004  Threatened Species: Vertebrates (number)     31
# 2     Afghanistan  2010  Threatened Species: Vertebrates (number)     31
# 3     Afghanistan  2015  Threatened Species: Vertebrates (number)     31
# 4     Afghanistan  2018  Threatened Species: Vertebrates (number)     34
# ...           ...   ...                                       ...    ...
# 6916     Zimbabwe  2015        Threatened Species: Total (number)     60
# 6917     Zimbabwe  2018        Threatened Species: Total (number)     95
# 6918     Zimbabwe  2019        Threatened Species: Total (number)    103
# 6919     Zimbabwe  2020        Threatened Species: Total (number)    122
# 6920     Zimbabwe  2021        Threatened Species: Total (number)    124
#
#      Unnamed: 5                                             Source
# ...

# %%
species = species.drop(0)

# %%
species = species.drop(['Unnamed: 5'],axis = 1)

# %%
species = species.drop(['Threatened species'],axis = 1)

# %%
species = species.rename(columns = {'Type': 'Count'})

# %%
species = species.drop(['Source'], axis = 1)

# %%
species = species.rename(columns = {'Value': 'Count'})

# %%
species
# Out:
#           Country  Year Count
# 1     Afghanistan  2004    31
# 2     Afghanistan  2010    31
# 3     Afghanistan  2015    31
# 4     Afghanistan  2018    34
# 5     Afghanistan  2019    33
# ...           ...   ...   ...
# 6916     Zimbabwe  2015    60
# 6917     Zimbabwe  2018    95
# 6918     Zimbabwe  2019   103
# 6919     Zimbabwe  2020   122
# 6920     Zimbabwe  2021   124
#
# [6920 rows x 3 columns]

# %%
species = species.set_index('Country')

# %%
species
# Out:
#              Year Count
# Country
# Afghanistan  2004    31
# Afghanistan  2010    31
# Afghanistan  2015    31
# Afghanistan  2018    34
# Afghanistan  2019    33
# ...           ...   ...
# Zimbabwe     2015    60
# Zimbabwe     2018    95
# Zimbabwe     2019   103
# Zimbabwe     2020   122
# Zimbabwe     2021   124
#
# [6920 rows x 2 columns]

# %%
species_america = species.loc[['United States of America']]

# %%
species_america
# Out:
#                           Year  Count
# Country
# United States of America  2004    342
# United States of America  2010    376
# United States of America  2015    444
# United States of America  2018    462
# United States of America  2019    479
# United States of America  2020    482
# United States of America  2021    506
# United States of America  2004    561
# United States of America  2010    531
# United States of America  2015    575
# United States of America  2018    580
# United States of America  2019    581
# United States of America  2020    586
# United States of America  2021    600
# United States of America  2004    240
# United States of America  2010    245
# United States of America  2015    280
# United States of America  2018    498
# United States of America  2019    556
# United States of America  2020    587
# United States of America  2021    735
# United States of America  2004  1,143
# United States of America  2010  1,152
# ...

# %%
species.groupby('Year')['Count'].count().plot(kind = 'bar', color = 'r', figsize = (8,6))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
species = species[species['Year'] == '2021']

# %%
species
# Out:
#             Country  Year Count
# 7       Afghanistan  2021    38
# 14      Afghanistan  2021     2
# 21      Afghanistan  2021     8
# 28      Afghanistan  2021    48
# 30    Åland Islands  2021     0
# ...             ...   ...   ...
# 6892         Zambia  2021   121
# 6899       Zimbabwe  2021    43
# 6906       Zimbabwe  2021     8
# 6913       Zimbabwe  2021    73
# 6920       Zimbabwe  2021   124
#
# [999 rows x 3 columns]

# %%
species = species.set_index('Country')

# %%
species
# Out:
#                Year Count
# Country
# Afghanistan    2021    38
# Afghanistan    2021     2
# Afghanistan    2021     8
# Afghanistan    2021    48
# Åland Islands  2021     0
# ...             ...   ...
# Zambia         2021   121
# Zimbabwe       2021    43
# Zimbabwe       2021     8
# Zimbabwe       2021    73
# Zimbabwe       2021   124
#
# [999 rows x 2 columns]

# %%
print(species.sort_values(by = 'Count', ascending = False).head(200))
# Out:
#                         Year Count
# Country
# Syrian Arab Republic    2021    99
# British Virgin Islands  2021    99
# Somalia                 2021    99
# Germany                 2021    98
# Yemen                   2021    97
# ...                      ...   ...
# New Caledonia           2021   629
# South Sudan             2021    62
# Czechia                 2021    62
# Norway                  2021    62
# Dominica                2021    62
#
# [200 rows x 2 columns]

# %%
pd.set_option('display.max_rows', species.shape[0]+1)
print(species)
# Out:
#                                Year  Count
# Country
# Afghanistan                    2021     38
# Afghanistan                    2021      2
# Afghanistan                    2021      8
# Afghanistan                    2021     48
# Åland Islands                  2021      0
# Åland Islands                  2021      0
# Åland Islands                  2021      1
# Åland Islands                  2021      1
# Albania                        2021     70
# Albania                        2021     72
# Albania                        2021      5
# Albania                        2021    147
# Algeria                        2021     96
# Algeria                        2021     42
# Algeria                        2021     32
# Algeria                        2021    170
# American Samoa                 2021     34
# American Samoa                 2021     66
# American Samoa                 2021      2
# American Samoa                 2021    102
# Andorra                        2021      6
# ...

# %%
species = species.loc[['United States of America']]

# %%
species
# Out:
#                           Year  Count
# Country
# United States of America  2021    506
# United States of America  2021    600
# United States of America  2021    735
# United States of America  2021  1,841

# %%
species = pd.read_csv('../data/SYB64_313_202110_Threatened Species.csv')

# %%
species
# Out:
#                       T23 Threatened species Unnamed: 2  \
# 0     Region/Country/Area                NaN       Year
# 1                       4        Afghanistan       2004
# 2                       4        Afghanistan       2010
# 3                       4        Afghanistan       2015
# 4                       4        Afghanistan       2018
# ...                   ...                ...        ...
# 6916                  716           Zimbabwe       2015
# 6917                  716           Zimbabwe       2018
# 6918                  716           Zimbabwe       2019
# 6919                  716           Zimbabwe       2020
# 6920                  716           Zimbabwe       2021
#
#                                     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                       Series      Value  Footnotes
# 1     Threatened Species: Vertebrates (number)         31        NaN
# 2     Threatened Species: Vertebrates (number)         31        NaN
# ...

# %%
species.set_index('T23')
# Out:
#                     Threatened species Unnamed: 2  \
# T23
# Region/Country/Area                NaN       Year
# 4                          Afghanistan       2004
# 4                          Afghanistan       2010
# 4                          Afghanistan       2015
# 4                          Afghanistan       2018
# ...                                ...        ...
# 716                           Zimbabwe       2015
# 716                           Zimbabwe       2018
# 716                           Zimbabwe       2019
# 716                           Zimbabwe       2020
# 716                           Zimbabwe       2021
#
#                                                    Unnamed: 3 Unnamed: 4  \
# T23
# Region/Country/Area                                    Series      Value
# 4                    Threatened Species: Vertebrates (number)         31
# 4                    Threatened Species: Vertebrates (number)         31
# ...

# %%
species.drop(0)
# Out:
#       T23 Threatened species Unnamed: 2  \
# 1       4        Afghanistan       2004
# 2       4        Afghanistan       2010
# 3       4        Afghanistan       2015
# 4       4        Afghanistan       2018
# 5       4        Afghanistan       2019
# ...   ...                ...        ...
# 6916  716           Zimbabwe       2015
# 6917  716           Zimbabwe       2018
# 6918  716           Zimbabwe       2019
# 6919  716           Zimbabwe       2020
# 6920  716           Zimbabwe       2021
#
#                                     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1     Threatened Species: Vertebrates (number)         31        NaN
# 2     Threatened Species: Vertebrates (number)         31        NaN
# 3     Threatened Species: Vertebrates (number)         31        NaN
# 4     Threatened Species: Vertebrates (number)         34        NaN
# 5     Threatened Species: Vertebrates (number)         33        NaN
# ...

# %%
species = species.set_index('T23')

# %%
species.loc[['Zimbabwe']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [197], in <cell line: 1>()
# ----> 1 species.loc[['Zimbabwe']]
#
# File ~\Anaconda\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Anaconda\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\Anaconda\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
# ...
